# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.ticker import PercentFormatter
 
import matplotlib.pyplot as plt
import os
os.chdir("/Users/Philip/Downloads")
df_b_listings = pd.read_csv("boston_listings_airbnb.csv")
df_c_listings = pd.read_csv("cambridge_listings_airbnb.csv")
df_c_calendar = pd.read_csv("cambridge_calendar2020_airbnb.csv")
df_b_calendar = pd.read_csv("boston_calendar2020_airbnb.csv")
df_c_reviews = pd.read_csv("cambridge_reviews2020_airbnb.csv")
df_b_reviews = pd.read_csv("boston_reviews2020_airbnb.csv")

# %%
df_b_listings['City']='Boston'

# %%
df_c_listings['City']='Cambridge'

# %%
df_listings = pd.concat([df_b_listings,df_c_listings])

# %%
df_listings.shape
# Out:
# (19974, 110)

# %%
df_c_calendar.shape
# Out:
# (1708606, 9)

# %%
df_b_calendar.shape
# Out:
# (5581943, 9)

# %%
df_b_calendar.columns
# Out:
# Index(['Unnamed: 0', 'listing_id', 'date', 'available', 'price',
#        'adjusted_price', 'minimum_nights', 'maximum_nights', 'Month'],
#       dtype='object')

# %%
df_b_calendar.drop_duplicates(subset='listing_id').shape
# Out:
# (4501, 9)

# %%
df2.drop_duplicates(subset='id').shape
# Out:
# (1363, 109)

# %%
df_b_reviews.shape
# Out:
# (176224, 7)

# %%
df_c_reviews.shape
# Out:
# (66484, 7)

# %%
df_b_reviews
# Out:
#         Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0                0        3781   37776825  2015-07-10     36059247
# 1                1        3781   41842494  2015-08-09     10459388
# 2                2        3781   45282151  2015-09-01     12264652
# 3                3        3781   49022647  2015-09-30     41426327
# 4                4        3781   52503327  2015-10-30     15151513
# 5                5        3781   63371931  2016-02-22     55456499
# 6                6        3781   67909504  2016-04-01     55456499
# 7                7        3781   97906006  2016-08-28     88528884
# 8                8        3781  105143774  2016-09-30      1342806
# 9                9        3781  129692749  2017-02-01     55126634
# 10              10        3781  155725362  2017-05-28    117390053
# 11              11        3781  184356065  2017-08-19     70187382
# 12              12        3781  194026175  2017-09-15     11888800
# ...

# %%
#df
#df.shape
#df.dtypes
#df.query('id=="3781"')

df.shape
#df.info()
# Out:
# (15293, 109)

# %%
plt.style.use('seaborn')
fig, axs = plt.subplots(2, 1, sharex=True,sharey=True)
fig.suptitle('Histogram with Density', fontsize=18)
filter1 = df.loc[:,"reviews_per_month"]<=10
axs[0].hist(df.loc[filter1, 'reviews_per_month'].dropna(),bins=30, color='b',edgecolor="black", density=True)
axs[0].yaxis.set_major_formatter(PercentFormatter(xmax=1))
axs[1].yaxis.set_major_formatter(PercentFormatter(xmax=1))
axs[0].set_title('Boston Reviews Per Month')
axs[1].set_title('Cambridge Reviews Per Month')
filter2 = df2.loc[:,"reviews_per_month"]<=10
axs[1].hist(df2.loc[filter2, 'reviews_per_month'].dropna(),bins=30, color = 'g',edgecolor="black", density=True)

plt.savefig('reviews_hist.png')

# %%
missing = df['listing_url'].isna()
df.loc[missing,:]

# %%
df['id'].describe(include='all')
# Out:
# count    1.529300e+04
# mean     2.459757e+07
# std      1.225095e+07
# min      3.781000e+03
# 25%      1.517415e+07
# 50%      2.479628e+07
# 75%      3.567550e+07
# max      4.317636e+07
# Name: id, dtype: float64

# %%
#df.groupby('id').describe().unstack(1)
# Out:
#                        id
# Unnamed: 0      count  3781        4.0
#                        5506        3.0
#                        6695        3.0
#                        8789        4.0
#                        10730       4.0
#                        10811       2.0
#                        10813       3.0
#                        10986       4.0
#                        16384       2.0
#                        18711       4.0
#                        22195       3.0
#                        22354       4.0
#                        24240       4.0
#                        27611       2.0
#                        29765       4.0
#                        40601       4.0
#                        44205       2.0
#                        45987       4.0
#                        60029       3.0
#                        60356       4.0
#                        67774       1.0
#                        69369       3.0
#                        77681       4.0
# ...

# %%
df_b_listings['cancellation_policy'].value_counts(normalize=True)
# Out:
# strict_14_with_grace_period    0.518015
# moderate                       0.242725
# flexible                       0.201922
# strict                         0.030602
# super_strict_30                0.004120
# super_strict_60                0.002616
# Name: cancellation_policy, dtype: float64

# %%
df_c_listings['cancellation_policy'].value_counts(normalize=True)
# Out:
# strict_14_with_grace_period    0.520402
# moderate                       0.261910
# flexible                       0.211921
# strict                         0.005768
# Name: cancellation_policy, dtype: float64

# %%
#fig, ax = plt.subplots()
#df_b_listings.plot.hist(column="cancellation_policy")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-a41fd1fc4035> in <module>
#       1 #fig, ax = plt.subplots()
# ----> 2 df_b_listings.plot.hist(column="cancellation_policy")
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwds)
#    3264             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    3265         """
# -> 3266         return self(kind='hist', by=by, bins=bins, **kwds)
#    3267
#    3268     @Appender(_kde_docstring % {
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
pd.set_option('display.max_columns', None)
df_listings.head()
# Out:
#    Unnamed: 0     id                         listing_url       scrape_id  \
# 0           0   3781   https://www.airbnb.com/rooms/3781  20200105171901
# 1           1   8789   https://www.airbnb.com/rooms/8789  20200105171901
# 2           2  10730  https://www.airbnb.com/rooms/10730  20200105171901
# 3           3  10811  https://www.airbnb.com/rooms/10811  20200105171901
# 4           4  10986  https://www.airbnb.com/rooms/10986  20200105171901
#
#   last_scraped                                              name  \
# 0   2020-01-05                         HARBORSIDE-Walk to subway
# 1   2020-01-05               Curved Glass Studio/1bd facing Park
# 2   2020-01-05                    Bright 1bed facing Golden Dome
# 3   2020-01-05  Back Bay Apt Studio-3 blocks to Pru center & "T"
# 4   2020-01-05   Waterfront/North End Furnished Large Studio Apt
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
# ...

# %%
#df_b_listings.groupby('cancellation_policy').size().plot(kind='bar', density=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-b635c4fe7aea> in <module>
# ----> 1 df_b_listings.groupby('cancellation_policy').value_counts().plot(kind='bar', density=True)
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
df_b_listings['cancellation_policy'].value_counts().plot(kind='bar')

# %%
#df_b_listings = sns.load_dataset("boston_listings_airbnb.csv")


sns.countplot(y="cancellation_policy", data=df_c_listings, orient='v').set_title('Cambridge Cancellation Policy Frequency')
plt.savefig('camcancfreq.png')

# %%
ax1 = sns.countplot(x="City", hue="cancellation_policy",orient = "h",data=df_listings)
ax1.legend(loc='upper right')
ax1.set_title('Cancellation Policies Distribution by City')
plt.savefig('cancellationfreq.jpg')

# %%
ax2 = sns.catplot(x="Month", y="reviews_per_month",hue="City",kind='box',data=df_listings)
#ax.legend(loc='upper right')
ax2.fig.suptitle('Reviews Per Month by City')
plt.savefig('reviewsbymonth.jpg')
