# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import glob
from matplotlib.ticker import PercentFormatter
import matplotlib.pyplot as plt
import os            
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#change DIRECTORY TO downloads where final outputs ARE

os.chdir("/Users/Philip/Downloads/Inside Airbnb Raw Data/2020")

# %%
cities = ["cambridge", "boston"]
df_reviews= []
df_reviews=pd.DataFrame(df_reviews)
months = ["jan","feb","mar","april","may","june","july","august","sept","oct","nov","dec"]

# %%
# imported the requests library
import requests
file = "http://data.insideairbnb.com/united-states/ma/cambridge/2021-02-25/data/reviews.csv.gz"
  
# URL of the image to be downloaded is defined as file
r = requests.get(file) # create HTTP response object
  
# send a HTTP request to the server and save
# the HTTP response in a response object called r
with open("cambridge reviews.csv.gz",'wb') as f:
  
    # write the contents of the response (r.content)
    # to a new file in binary mode.
    f.write(r.content)

#cities = ["Cambridge", "Boston"]
# Out:
# 4110126

# %%
#for i in cities:
 #       df = pd.read_csv(str(i)+" reviews.csv")   
 #       df['City']=i
 #       df_reviews=pd.concat([df_reviews,df])

#df_reviews
#df_reviews['City']

# %%
for i in months:
        df = pd.read_csv("reviews_"+str(i)+"_2020.csv")   
        df['Month']=i
        df_reviews=pd.concat([df_reviews,df])

# %%
sum(df_reviews.duplicated())
# Out:
# 0

# %%
df_reviews
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0             3781   37776825  2015-07-10     36059247              Greg
# 1             3781   41842494  2015-08-09     10459388               Tai
# 2             3781   45282151  2015-09-01     12264652            Damien
# 3             3781   49022647  2015-09-30     41426327              Mike
# 4             3781   52503327  2015-10-30     15151513              Ivan
# ...            ...        ...         ...          ...               ...
# 117536    46579706  716504973  2020-12-19     93225917            Betina
# 117537    46605778  713767182  2020-12-06     65805853         Chantalle
# 117538    46621676  713827462  2020-12-06     72276574             Staci
# 117539    46627405  712836333  2020-12-01    210206181  Dietrich Blocker
# 117540    46819851  714712772  2020-12-11     30969268          Julianne
#
#                                                  comments Month
# 0       The apartment was as advertised and Frank was ...   jan
# 1       It was a pleasure to stay at Frank's place. Th...   jan
# 2       The apartment description is entirely faithful...   jan
# 3       Thoroughly enjoyed my time at Frank's home. Ha...   jan
# 4       Great value for the money! This location has e...   jan
# ...                                                   ...   ...
# 117536  Great and central location! Close to everything !   dec
# 117537  Great spot that I highly recommend. Looks exac...   dec
# 117538  Michelle is very responsive and helped us with...   dec
# 117539          Great space for exactly what you require.   dec
# 117540  Nice convenient stay! The location is right in...   dec
#
# [1664177 rows x 7 columns]

# %%
df_review_final = df_reviews[df_reviews.duplicated(subset = ['comments'],keep='last')]

# %%
sum(df_review_final.duplicated(['comments']))
# Out:
# 1300640

# %%
df = df_reviews
df['Year'] = pd.DatetimeIndex(df['date']).year
# df['Month']=pd.DatetimeIndex(df['date']).strftime("%B")
df['Month'] = pd.DatetimeIndex(df['date']).month

#Fixed to include all months of the year from 2017 on

df.drop(df[(df["Year"] < 2020) | (df["Month"] < 1) ].index, inplace = True)

# %%
df
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 151320    34212943  586152360  2020-01-01    321983634           Ian
# 156424    38401377  586304980  2020-01-01    182763514            Yu
# 156878    39479603  586309895  2020-01-01    310274880         Kathy
# 156941    39583307  586163011  2020-01-01    300307735         Frida
# 157183    40900669  587817094  2020-01-03    321604573        Shante
# ...            ...        ...         ...          ...           ...
# 161632    41838589  602726490  2020-02-07     31144173          Mary
# 161633    41889162  601002020  2020-02-02    235976114          Abdi
# 161634    42074896  603644800  2020-02-09    134720980         Sonia
# 151320    38128388  601432615  2020-02-03    182876150       Wei-Min
# 151320    38666086  613230039  2020-03-01    144178195        Ashley
#
#                                                  comments  Month  Year
# 151320                                 Good place to stay      1  2020
# 156424  The whole stay was perfect.  The room is big a...      1  2020
# 156878                           Emplacement exceptionnel      1  2020
# 156941                                            Perfekt      1  2020
# 157183  Nice location easy access to train station ......      1  2020
# ...                                                   ...    ...   ...
# 161632  This efficiency unit was great for a work trip...      2  2020
# 161633     Great host! And great place! Enjoyed it a lot.      2  2020
# 161634  What an amazing stay in a great location. We w...      2  2020
# 151320  This is the greatest experience!It is very cle...      2  2020
# 151320                                   Very hospitable!      3  2020
#
# [1082 rows x 8 columns]

# %%
df.drop_duplicates(subset=['date','comments'], keep='first', inplace=True)
df
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 151320    34212943  586152360  2020-01-01    321983634           Ian
# 156424    38401377  586304980  2020-01-01    182763514            Yu
# 156878    39479603  586309895  2020-01-01    310274880         Kathy
# 156941    39583307  586163011  2020-01-01    300307735         Frida
# 157183    40900669  587817094  2020-01-03    321604573        Shante
# ...            ...        ...         ...          ...           ...
# 161631    41820180  604776757  2020-02-12     39657534      Marquita
# 161632    41838589  602726490  2020-02-07     31144173          Mary
# 161633    41889162  601002020  2020-02-02    235976114          Abdi
# 161634    42074896  603644800  2020-02-09    134720980         Sonia
# 151320    38666086  613230039  2020-03-01    144178195        Ashley
#
#                                                  comments  Month  Year
# 151320                                 Good place to stay      1  2020
# 156424  The whole stay was perfect.  The room is big a...      1  2020
# 156878                           Emplacement exceptionnel      1  2020
# 156941                                            Perfekt      1  2020
# 157183  Nice location easy access to train station ......      1  2020
# ...                                                   ...    ...   ...
# 161631  An is absolutely AMAZING!!! Sooo nice, so cour...      2  2020
# 161632  This efficiency unit was great for a work trip...      2  2020
# 161633     Great host! And great place! Enjoyed it a lot.      2  2020
# 161634  What an amazing stay in a great location. We w...      2  2020
# 151320                                   Very hospitable!      3  2020
#
# [1075 rows x 8 columns]

# %%
df['count'] = (df.groupby(["Year", "Month",'listing_id'])['Month'].transform('count'))

# %%
sum(df['count'])
# Out:
# 4257

# %%
result = pd.merge(df_listings,df_reviews, on="listing_id")

# %%
result.head(5)
# Out:
#     id_x                         listing_url       scrape_id last_scraped  \
# 0  18711  https://www.airbnb.com/rooms/18711  20210219004231   2021-02-20
# 1  18711  https://www.airbnb.com/rooms/18711  20210219004231   2021-02-20
# 2  18711  https://www.airbnb.com/rooms/18711  20210219004231   2021-02-20
# 3  18711  https://www.airbnb.com/rooms/18711  20210219004231   2021-02-20
# 4  18711  https://www.airbnb.com/rooms/18711  20210219004231   2021-02-20
#
#                                                 name  \
# 0  The Dorset Redline | 3BR 1BA | Walk to Redline...
# 1  The Dorset Redline | 3BR 1BA | Walk to Redline...
# 2  The Dorset Redline | 3BR 1BA | Walk to Redline...
# 3  The Dorset Redline | 3BR 1BA | Walk to Redline...
# 4  The Dorset Redline | 3BR 1BA | Walk to Redline...
#
#                                          description  \
# 0  Hospital Grade Sanitation Performed!  - Minimu...
# 1  Hospital Grade Sanitation Performed!  - Minimu...
# 2  Hospital Grade Sanitation Performed!  - Minimu...
# 3  Hospital Grade Sanitation Performed!  - Minimu...
# 4  Hospital Grade Sanitation Performed!  - Minimu...
#
#                                neighborhood_overview  \
# 0  Once its own city, Dorchester is now Boston’s ...
# 1  Once its own city, Dorchester is now Boston’s ...
# 2  Once its own city, Dorchester is now Boston’s ...
# 3  Once its own city, Dorchester is now Boston’s ...
# 4  Once its own city, Dorchester is now Boston’s ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/509158a7-36bc...    71783
# 1  https://a0.muscache.com/pictures/509158a7-36bc...    71783
# 2  https://a0.muscache.com/pictures/509158a7-36bc...    71783
# 3  https://a0.muscache.com/pictures/509158a7-36bc...    71783
# 4  https://a0.muscache.com/pictures/509158a7-36bc...    71783
#
#                                   host_url  ... reviews_per_month listing_id  \
# 0  https://www.airbnb.com/users/show/71783  ...               0.4      18711
# 1  https://www.airbnb.com/users/show/71783  ...               0.4      18711
# 2  https://www.airbnb.com/users/show/71783  ...               0.4      18711
# 3  https://www.airbnb.com/users/show/71783  ...               0.4      18711
# 4  https://www.airbnb.com/users/show/71783  ...               0.4      18711
#
#         id_y        date reviewer_id reviewer_name  \
# 0  151881710  2017-05-14    48793631          Lori
# 1  158611492  2017-06-07    45298490           Han
# 2  161840259  2017-06-18    77062274    Yeri Alice
# 3  172678896  2017-07-21    73656489     Alejandro
# 4  180515253  2017-08-10   110362686     Sébastien
#
#                                             comments    City  Year Month
# 0  The Dorset was clean and comfortable. I apprec...  boston  2017     5
# 1  The apartment is super big. Beds are comfortab...  boston  2017     6
# 2  The house was approachable from public transpo...  boston  2017     6
# 3               All is perfect, I recommend It 100 %  boston  2017     7
# 4  Perfectly located and well equipped, but extre...  boston  2017     8
#
# [5 rows x 83 columns]

# %%
#Add Count column by grouping
#df=df.groupby(["Year", "Month"])["Year"].count().reset_index(name="count")
df['count'] = (df.groupby(["Year", "Month",'listing_id'])['Month'].transform('count'))

# %%
test = df[["Year", "Month","count",'listing_id']]
test.drop_duplicates(subset=['Year','Month'], inplace=True)
# test.shape
test.sort_values(by=['Year', 'Month'])
# Out:
# <ipython-input-16-50652d9e9188>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop_duplicates(subset=['Year','Month'], inplace=True)
#       Year  Month  count  listing_id
# 720   2017      1      2       79762
# 722   2017      2      2       79762
# 208   2017      3      1       11945
# 159   2017      4      2       11169
# 161   2017      5      1       11169
# 162   2017      6      1       11169
# 741   2017      7      1       79762
# 742   2017      8      2       79762
# 926   2017      9      2      219471
# 163   2017     10      3       11169
# 1852  2017     11      2      715532
# 2700  2017     12      1     1140201
# 3853  2018      1      4     1200294
# 3857  2018      2      3     1200294
# 1854  2018      3      1      715532
# 166   2018      4      2       11169
# 168   2018      5      2       11169
# 170   2018      6      1       11169
# 171   2018      7      2       11169
# 460   2018      8      2       24063
# 173   2018      9      2       11169
# 175   2018     10      1       11169
# 176   2018     11      1       11169
# 1488  2018     12      2      456429
# 468   2019      1      1       24063
# 1890  2019      2      1      715532
# 469   2019      3      1       24063
# 213   2019      4      1       11945
# 177   2019      5      1       11169
# 473   2019      6      2       24063
# 178   2019      7      1       11169
# 498   2019      8      1       27498
# 179   2019      9      1       11169
# 1918  2019     10      5      715532
# 480   2019     11      4       24063
# 1928  2019     12      2      715532
# 180   2020      1      1       11169
# 214   2020      2      1       11945
# 1930  2020      3      1      715532
# 6291  2020      4      1     1984737
# 4657  2020      5      1     1330779
# 6292  2020      6      2     1984737
# 6294  2020      7      2     1984737
# 2706  2020      8      1     1140201
# 3127  2020      9      1     1141088
# 6298  2020     10      2     1984737
# 2707  2020     11      1     1140201
# 4013  2020     12      1     1203031
# 3128  2021      1      2     1141088
# 3925  2021      2      1     1200294

# %%
test.shape
# Out:
# (50, 4)

# %%
ttest.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-747381078d82> in <module>
# ----> 1 ttest.columns
#
# NameError: name 'ttest' is not defined

# %%
stats.ttest_rel(ttest["2019"],ttest["2020"])

# %%
#T test comparing 2019 to 2020 for each month???
ttest = test.pivot_table(index=['Month'], 
                      columns='Year', 
                      values='count', 
                      aggfunc='first').reset_index().rename_axis(None, axis=1)
#ttest.columns = ['Month','2018','2019','2020']
stats.ttest_rel(ttest['2019'],ttest['2020'])

# %%
ttest.columns

# %%
df.groupby(['Year','Month']).size()

# %%
df

# %%
# df['count'] = df.groupby(['Year']['Month'])['Month'].transform('count')

# %%
#Add count variable 


# df = pd.read_csv("reviews.csv") 
# df['Year'] = pd.DatetimeIndex(df['date']).year
# # df['Month']=pd.DatetimeIndex(df['date']).strftime("%B")
# df['Month'] = pd.DatetimeIndex(df['date']).month
# df.drop(df[(df["Year"] < 2018) | (df["Month"] < 3) ].index, inplace = True)
df=df.groupby(["Year", "Month"])["Year"].count().reset_index(name="count")

# %%
# Save a palette to a variable:
palette = sns.color_palette("bright")
 
# Use palplot and pass in the variable:
sns.palplot(palette)

# %%
ax = sns.lineplot(x="Month", y="count", hue="Year",data=df, palette=sns.color_palette('bright', n_colors=3))
# ax.text(x,y, df['count'])
# label = '{.2f}'.format(df['count'])
# plt.annotate(label,  (x,y))
plt.suptitle('Number of Reviews in Boston and Cambridge')
plt.xlim(3, 12)
plt.savefig("Year on Year.png")

# %%
#Find Unique properties ids number of comments per unique properties
df_reviews=pd.merge(df,df.groupby(['Year','Month'],as_index=False).count(), on=['Year','Month'])

# %%
df_reviews

# %%
#PERCENT OF REVIEWS COLUMNS HAVE NAN
(len(df_reviews)-df_reviews.count())/len(df_reviews))

# %%
#percentage OF NAs by feature
(len(df_calendar)-df_calendar.count())/len(df_calendar)

# %%
#SET THE STYLE
sns.set(style="darkgrid")

# %%
ax3 = sns.catplot(x="Month", y="adjusted_price",hue="City",kind='box',data=df_calendar,height=12, aspect=1, showfliers=False, palette=sns.color_palette(['purple', 'yellow']))
#ax.legend(loc='upper right')
ax3.fig.suptitle('Adjusted Price Per Month by City')
#ax3.set_yscale("log")
#plt.yscale('log')
plt.savefig('adjprice.jpg')

# %%
ax9 = sns.catplot(x="City",y='price',hue='Month', kind='box',showfliers=False,data=df_listings)
#ax.legend(loc='upper right')
ax9.fig.suptitle('Listing Prices Box Plot')
#plt.ylim(0, 30)
plt.savefig('listingprices.jpg')
